# %%
from PIL import Image
import PIL
import os

# %%
root = './data/images/lfw_aligned/'

err = []
for folder in os.listdir(root):
    tmp = os.path.join(root, folder)
    for img in os.listdir(tmp):
        img_path = os.path.join(tmp, img)
        try:
            im = Image.open(img_path)
        except PIL.UnidentifiedImageError:
            print("error with", img_path)
            err.append(img_path)

# %%
len(err)
# Out:
# 0

# %%
os.path.split(err[0])
# Out:
# ('./data/images/lfw_aligned/Alex_Gonzalez', 'Alex_Gonzalez_0001.jpg')

# %%
origin = './data/images/lfw/Alex_Gonzalez/Alex_Gonzalez_0001.jpg'
im = Image.open(origin)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x22A8717F550>

# %%
from deepface import DeepFace

# %%
detection = DeepFace.detectFace(origin, detector_backend='mtcnn')
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000022ADD376550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
face = Image.fromarray(np.uint8(detection*255))

# %%
face.save('test.jpg')

# %%
len_aligned = 0
for folder in os.listdir(root):
    tmp = os.path.join(root, folder)
    len_aligned += len(os.listdir(tmp))

len_aligned
# Out:
# 13233

# %%
origin = './data/images/lfw/'

len_lfw = 0
for folder in os.listdir(origin):
    tmp = os.path.join(origin, folder)
    len_lfw += len(os.listdir(tmp))

len_lfw
# Out:
# 13233

# %%
import os

for path in err:
    os.remove(path)

# %%
origin = './data/images/lfw/'
root = './data/images/lfw_aligned/'
targets = []
for img in err:
    head, file = os.path.split(img)
    folder = os.path.split(head)[1]
    fname = os.path.join(origin, folder, file)
    target = os.path.join(root, folder, file)
    targets.append(target)
    face = DeepFace.detectFace(fname, detector_backend='mtcnn')
    im = Image.fromarray(np.uint8(detection*255))
    im.save(target)
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000022ADFAE89D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
Image.open(targets[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x22ADF7EF7C0>
